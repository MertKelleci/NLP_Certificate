# %% [markdown]
# # Derin Öğrenme Tabanlı Modern Dil Modelleri
#
# ## Table of Content:
# - [1. Recurrent Neural Networks(RNN)](#1.-Recurrent-Neural-Networks-(RNN):)
# - [2. Long Short-Term Memory (LSTM)](#2.-Long-Short-Term-Memory-(LSTM):)
# - [3. Transformers (GPT & LLAMA)](#3.-Transformers-(GPT-&-LLAMA):)

# %% [markdown]
# # 1. Recurrent Neural Networks (RNN):
#
# - Sekans verileri işlemek için özel olarak tasarlanmış sinir ağlarıdır.
# - Her zaman adımında, önceki zaman adımındaki bilgiyi saklayarak ve sonraki adımlarla bu bilgiyi güncelleyerek çalışır.
# - **RNN Temel Özellikleri:**
#     - Zaman boyutunda tekrar
#     - Sekans verisi için uygun
#
# ![RNN Mimarisi](https://media.geeksforgeeks.org/wp-content/uploads/20260429164557969550/introduction_to_recurrent_neural_network.webp)
# - **Zaman Serisi:** Zaman içerisinde ardışık olarak kaydedilen *(finans, iklim, sensör vs.)* verilerdir.
# - **Sekans Verisi:** Doğal sıralı bağlılıkları olan *(doğal dil, konuşma tanıma, DNA dizileri vs.)* verilerdir.
# - **Dil ve Zaman Serisi Verilerinde Dizisel Bağımlılık:** Zaman serisi ve dil verilerinde, her bir öğe sırasıyla önceki öğelere bağımlıdır *(Cümledeki kelimenin anlamının bir önceki kelimelere bağımlı olması, hava sıcaklığı tahmininde tahmin edilecek durumun daha önceki günlere bağımlı olması vs.)*.
# - **Standart Sinir Ağları Sekans Verilerinde Neden Yetersizdir:**
#     - Sabit girdi/çıktı
#     - Zaman bağımlılığı
#     - Geçmiş bilgiyi kaybetme
# - **Vanishing Gradient Sorunu:**
#     - RNN'lerde eğitim sırasında ortay çıkar.
#     - Backpropagation sırasında, gradyanlar çok küçük hale gelir ve bu uzun süreli bağımlılıkların öğrenilmesini zorlaştırır.
#     - Her zaman adımında alınan zincirleme türevler zaman içinde küçülür ve neredeyse sıfıra yaklaşır. Bu durumda önceki adımlardaki bilginin etkisi kaybolur. Bu sebeple, kısa dönem bağımlılıklar öğrenilirken uzun dönem bağımlılıkların kaybolur.
# - **Kullanım Alanları:**
#     - Dil modelleme
#     - Makine çevirisi
#     - Duygu analizi
#     - Konuşma tanıma
#     - Metin üretimi

# %%
import numpy as np
import pandas as pd

from gensim.models import Word2Vec
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense, Embedding
from keras.layers import TextVectorization
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
imdb_df = pd.read_csv("IMDB Dataset.csv")
imdb_df.head(5)
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
import re
from bs4 import BeautifulSoup as bs
from nltk.corpus import stopwords

stop_words_eng = stopwords.words("english")

def clean_text(text):
    text = text.lower()
    text = bs(text, "html.parser").get_text()

    # Text temizliği:
    # Kelimeler arasındaki '-' karakterleri
    # Lookarounds:   (?=) - positive lookahead
    #                (?!) - negative lookahead
    #                (?<=) - positive lookbehind
    #                (?<!) - negative lookbehind
    text = re.sub(r"(?<=\w)-(?=\w)", " ", text)
    # Harf olmayan karakterlerin tamamı:
    text = re.sub(r"[^A-Za-z\s]", "", text)
    # Peşpeşe birden fazla kez gelen boşluk karakterleri:
    text = re.sub(r"\s{2,}", "", text)
    # Sık kullanılan farklı yazımlar: \b => word boundary 
    text = re.sub(r"cannot", "can not", text)
    text = re.sub(r"\bim\b", "i am", text)

    ttokens = text.split()
    text = " ".join([word for word in ttokens if word not in stop_words_eng])

    return text

# %%
clean_text(imdb_df["review"].iloc[1])
# Out:
# 'wonderful little production filming technique unassuming old time bbc fashion gives comforting sometimes discomforting sense realism entire piece actors extremely well chosen michael sheen got polari voices pat truly see seamless editing guided references williams diary entries well worth watching terrificly written performed piece masterful production one great masters comedy life realism really comes home little things fantasy guard rather use traditional dream techniques remains solid disappears plays knowledge senses particularly scenes concerning orton halliwell sets particularly flat halliwells murals decorating every surface terribly well done'

# %%
cleaned_reviews = imdb_df["review"].iloc[:5000].apply(clean_text)

# %%
vectorize_layer = TextVectorization(output_mode="int", max_tokens=5000, output_sequence_length=500)
vectorize_layer.adapt(cleaned_reviews, batch_size=500)

# %%
sequences = vectorize_layer(cleaned_reviews)

# %%
sequences.shape
# Out:
# TensorShape([5000, 500])

# %%
# label encoding
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(imdb_df["sentiment"].iloc[:5000])
y[:5]
# Out:
# array([1, 1, 1, 0, 1])

# %%
sequences.numpy()
# Out:
# array([[   4, 1718,  806, ...,    0,    0,    0],
#        [ 250,   32,  240, ...,    0,    0,    0],
#        [  94,  250,   24, ...,    0,    0,    0],
#        ...,
#        [   1,    1,  809, ...,    0,    0,    0],
#        [1402,    2, 2417, ...,    0,    0,    0],
#        [  82, 1408,   29, ...,    0,    0,    0]], shape=(5000, 500))

# %%
x_train, x_test, y_train, y_test = train_test_split(sequences.numpy(), y, test_size=0.33, random_state=60)

# %%
treviews_list = [review.split() for review in cleaned_reviews]

# %%
# Metin temsili:
word2vec_model = Word2Vec(treviews_list, window = 5, vector_size=50, min_count=10, sg = 0)
# Out:
# Exception ignored in: 'gensim.models.word2vec_inner.our_dot_float'

# %%
# Eğitim sırasında oluşuturulan W2V modelindeki kelime vektörleri embedding matrix'e ekledik.

embedding_dim = 50
embedding_matrix = np.zeros((len(vectorize_layer.get_vocabulary(include_special_tokens=False))+2, embedding_dim))
i = 0
for word in vectorize_layer.get_vocabulary(include_special_tokens=False):
    if word in word2vec_model.wv:
        embedding_matrix[i] = word2vec_model.wv[word]
    i+=1

# %%
model = Sequential()

model.add(Embedding(len(vectorize_layer.get_vocabulary()), output_dim = embedding_dim, weights = [embedding_matrix], input_length=5000, trainable=False))
model.add(SimpleRNN(50))
model.add(Dense(1, activation="sigmoid"))


model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

model.fit(x_train, y_train, epochs = 50, batch_size=500, validation_data=(x_test,y_test))
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 378ms/step - accuracy: 0.5036 - loss: 0.7013 - val_accuracy: 0.5030 - val_loss: 0.6950
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 304ms/step - accuracy: 0.5084 - loss: 0.6947 - val_accuracy: 0.5030 - val_loss: 0.6941
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.4875 - loss: 0.6953 - val_accuracy: 0.5030 - val_loss: 0.6940
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 309ms/step - accuracy: 0.5090 - loss: 0.6937 - val_accuracy: 0.5030 - val_loss: 0.6945
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 298ms/step - accuracy: 0.4952 - loss: 0.6933 - val_accuracy: 0.4945 - val_loss: 0.6936
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 277ms/step - accuracy: 0.5012 - loss: 0.6935 - val_accuracy: 0.5042 - val_loss: 0.6935
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 316ms/step - accuracy: 0.5116 - loss: 0.6923 - val_accuracy: 0.4964 - val_loss: 0.6932
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 316ms/step - accuracy: 0.5030 - loss: 0.6927 - val_accuracy: 0.5048 - val_loss: 0.6938
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 312ms/step - accuracy: 0.4955 - loss: 0.6930 - val_accuracy: 0.5055 - val_loss: 0.6926
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - accuracy: 0.5015 - loss: 0.6921 - val_accuracy: 0.5055 - val_loss: 0.6931
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 308ms/step - accuracy: 0.5101 - loss: 0.6926 - val_accuracy: 0.4976 - val_loss: 0.6925
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - accuracy: 0.4907 - loss: 0.6936 - val_accuracy: 0.5061 - val_loss: 0.6932
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 278ms/step - accuracy: 0.5104 - loss: 0.6935 - val_accuracy: 0.5061 - val_loss: 0.6925
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 321ms/step - accuracy: 0.4901 - loss: 0.6931 - val_accuracy: 0.5055 - val_loss: 0.6926
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 303ms/step - accuracy: 0.5104 - loss: 0.6927 - val_accuracy: 0.5055 - val_loss: 0.6926
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 316ms/step - accuracy: 0.5104 - loss: 0.6921 - val_accuracy: 0.5061 - val_loss: 0.6924
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - accuracy: 0.4872 - loss: 0.6931 - val_accuracy: 0.5061 - val_loss: 0.6924
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 313ms/step - accuracy: 0.5104 - loss: 0.6927 - val_accuracy: 0.5061 - val_loss: 0.6926
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 312ms/step - accuracy: 0.4970 - loss: 0.6923 - val_accuracy: 0.5061 - val_loss: 0.6923
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 288ms/step - accuracy: 0.5104 - loss: 0.6919 - val_accuracy: 0.5061 - val_loss: 0.6927
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 328ms/step - accuracy: 0.4988 - loss: 0.6920 - val_accuracy: 0.5061 - val_loss: 0.6923
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 312ms/step - accuracy: 0.5107 - loss: 0.6917 - val_accuracy: 0.5061 - val_loss: 0.6925
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 332ms/step - accuracy: 0.4818 - loss: 0.6923 - val_accuracy: 0.5061 - val_loss: 0.6924
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 307ms/step - accuracy: 0.5107 - loss: 0.6933 - val_accuracy: 0.5061 - val_loss: 0.6922
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - accuracy: 0.4994 - loss: 0.6921 - val_accuracy: 0.4976 - val_loss: 0.6923
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 317ms/step - accuracy: 0.5113 - loss: 0.6915 - val_accuracy: 0.5061 - val_loss: 0.6926
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 263ms/step - accuracy: 0.5107 - loss: 0.6918 - val_accuracy: 0.5061 - val_loss: 0.6922
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 310ms/step - accuracy: 0.4934 - loss: 0.6921 - val_accuracy: 0.5061 - val_loss: 0.6922
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 303ms/step - accuracy: 0.5107 - loss: 0.6914 - val_accuracy: 0.5061 - val_loss: 0.6929
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.4958 - loss: 0.6920 - val_accuracy: 0.5061 - val_loss: 0.6922
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - accuracy: 0.5107 - loss: 0.6914 - val_accuracy: 0.5061 - val_loss: 0.6922
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - accuracy: 0.4893 - loss: 0.6923 - val_accuracy: 0.5061 - val_loss: 0.6923
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 312ms/step - accuracy: 0.5110 - loss: 0.6919 - val_accuracy: 0.5061 - val_loss: 0.6925
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 280ms/step - accuracy: 0.5054 - loss: 0.6913 - val_accuracy: 0.4976 - val_loss: 0.6923
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 306ms/step - accuracy: 0.5027 - loss: 0.6916 - val_accuracy: 0.5061 - val_loss: 0.6930
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 307ms/step - accuracy: 0.5003 - loss: 0.6918 - val_accuracy: 0.5061 - val_loss: 0.6922
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 313ms/step - accuracy: 0.5110 - loss: 0.6913 - val_accuracy: 0.5055 - val_loss: 0.6930
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step - accuracy: 0.5110 - loss: 0.6911 - val_accuracy: 0.4976 - val_loss: 0.6923
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 312ms/step - accuracy: 0.4896 - loss: 0.6921 - val_accuracy: 0.5061 - val_loss: 0.6922
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - accuracy: 0.4916 - loss: 0.6918 - val_accuracy: 0.5061 - val_loss: 0.6923
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 272ms/step - accuracy: 0.5110 - loss: 0.6912 - val_accuracy: 0.5061 - val_loss: 0.6925
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 335ms/step - accuracy: 0.5101 - loss: 0.6911 - val_accuracy: 0.4976 - val_loss: 0.6925
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 333ms/step - accuracy: 0.4949 - loss: 0.6924 - val_accuracy: 0.5061 - val_loss: 0.6930
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 319ms/step - accuracy: 0.5110 - loss: 0.6916 - val_accuracy: 0.5061 - val_loss: 0.6922
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 316ms/step - accuracy: 0.5110 - loss: 0.6911 - val_accuracy: 0.5061 - val_loss: 0.6922
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 319ms/step - accuracy: 0.5110 - loss: 0.6910 - val_accuracy: 0.5055 - val_loss: 0.6922
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 347ms/step - accuracy: 0.5110 - loss: 0.6919 - val_accuracy: 0.5048 - val_loss: 0.6923
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 302ms/step - accuracy: 0.4884 - loss: 0.6918 - val_accuracy: 0.5061 - val_loss: 0.6922
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - accuracy: 0.5110 - loss: 0.6913 - val_accuracy: 0.5061 - val_loss: 0.6926
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 318ms/step - accuracy: 0.5110 - loss: 0.6911 - val_accuracy: 0.5055 - val_loss: 0.6921

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

print(f"Test loss: {test_loss}\nTest accuracy: {test_acc}")
# Out:
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.5048 - loss: 0.6928
# Test loss: 0.6927557587623596
# Test accuracy: 0.5048484802246094

# %% [markdown]
# ## 2. Long Short-Term Memory (LSTM):
#
# - RNN türlerinden biridir. Uzun vadeli bağımlılıkları öğrenebilmek için özel olarak tasarlanmıştır.
# - Zaman bağımlı verilerde uzun dönem bağımlılıkları öğrenmek ve **vanishing gradient** sorununu çözmek için geliştirilmiştir.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
gpt_df = pd.read_csv("GPT_Text.csv")
gpt_df.head()
# Out:
#                                      text  Unnamed: 1
# 0              Bugün hava oldukça sakindi         NaN
# 1          Sabah erkenden penceremi açtım         NaN
# 2  Güneş bulutların arasından görünüyordu         NaN
# 3         Kuşlar bahçede neşeyle ötüyordu         NaN
# 4          Çocuklar parkta oyun oynuyordu         NaN

# %%
gpt_df.drop("Unnamed: 1", axis=1, inplace=True)

# %%
gpt_df.head()
# Out:
#                                      text
# 0              Bugün hava oldukça sakindi
# 1          Sabah erkenden penceremi açtım
# 2  Güneş bulutların arasından görünüyordu
# 3         Kuşlar bahçede neşeyle ötüyordu
# 4          Çocuklar parkta oyun oynuyordu

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(gpt_df["text"])

# %%
# n-gram dizilerinin ve padding uygulanması
input_sequences = []
for text in gpt_df["text"]:
    token_list = tokenizer.texts_to_sequences([text])[0]

    for i in range (1, len(token_list)):
        input_sequences.append(token_list[:i+1])

# %%
input_sequences[:5]
# Out:
# [[8, 18], [8, 18, 15], [8, 18, 15, 147], [10, 231], [10, 231, 1198]]

# %%
# max uzunluğun bulunması ve padding
max_seq_len = max(len(x) for x in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen = max_seq_len, padding = "pre")

# %%
X, y = input_sequences[:, :-1], input_sequences[:, -1]

# one-hot encoding
y = tf.keras.utils.to_categorical(y, len(tokenizer.word_index)+1)

# %%
total_words = len(tokenizer.word_index)+1
model = Sequential()
model.add(Embedding(total_words, 50, input_length = X.shape[1]))
model.add(LSTM(100, return_sequences = False))
model.add(Dense(total_words, activation="softmax"))

model.compile(optimizer="adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

model.fit(X,y, epochs = 100, verbose = 0)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# C:\Users\mrtke\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:123: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
def generate_text(seed_text, next_words):
    for _ in range(next_words):
        # girdi verilerini sayısal değere dönüştür
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_seq_len-1, padding="pre")
        pred_probabilites = model.predict(token_list, verbose = 0)

        # En yüksek olasılığa sahip kelime
        pw_index = np.argmax(pred_probabilites, axis = -1)

        # tokenizer_list'ten kelimenin çekilmesi
        pw = tokenizer.index_word[pw_index[0]]

        seed_text = seed_text + " " + pw
    return seed_text

# %%
generate_text("Kitap yazmak", 6)
# Out:
# 'Kitap yazmak gittikçe daha heyecanlı hale geldi dönüş'

# %% [markdown]
# ### 3. Transformers (GPT & LLAMA):

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
